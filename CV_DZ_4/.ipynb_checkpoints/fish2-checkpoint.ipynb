# %%
import os, cv2, random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Подключаем plaidml для видеокарт AMD

# %%
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"
import plaidml.keras
plaidml.keras.install_backend()

# %%
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Convolution2D, MaxPooling2D, ZeroPadding2D, Dense, Activation
from keras.optimizers import RMSprop, Adam
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
from keras import backend as K

# %%
TRAIN_DIR = "C:/Users/admin/DS/CV/input/"
TEST_DIR = 'C:/Users/admin/DS/CV/test_stg1/'
TEST_DIR2 = 'C:/Users/admin/DS/CV/test_stg2/'
FISH_CLASSES = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']
ROWS = 90  #720
COLS = 160 #1280
CHANNELS = 3

# %% [markdown]
# ### Загружаем данные

# %%
def get_images(fish):
    """Load files from train folder"""
    fish_dir = TRAIN_DIR+'{}'.format(fish)
    images = [fish+'/'+im for im in os.listdir(fish_dir)]
    return images

def read_image(src):
    """Read and resize individual images"""
    im = cv2.imread(src, cv2.IMREAD_COLOR)
    im = cv2.resize(im, (COLS, ROWS), interpolation=cv2.INTER_CUBIC)
    return im


files = []
y_all = []

for fish in FISH_CLASSES:
    fish_files = get_images(fish)
    files.extend(fish_files)
    
    y_fish = np.tile(fish, len(fish_files))
    y_all.extend(y_fish)
    print("{0} photos of {1}".format(len(fish_files), fish))
    
y_all = np.array(y_all)
# Out:
# 1719 photos of ALB
# 200 photos of BET
# 117 photos of DOL
# 67 photos of LAG
# 465 photos of NoF
# 299 photos of OTHER
# 176 photos of SHARK
# 734 photos of YFT

# %%
X_all = np.ndarray((len(files), ROWS, COLS, CHANNELS), dtype=np.uint8)

for i, im in enumerate(files): 
    X_all[i] = read_image(TRAIN_DIR+im)
    if i%1000 == 0: print('Processed {} of {}'.format(i, len(files)))

print(X_all.shape)
# Out:
# Processed 0 of 3777
# Processed 1000 of 3777
# Processed 2000 of 3777
# Processed 3000 of 3777
# (3777, 90, 160, 3)

# %% [markdown]
# ### Делаем One Hot Encoding для Labels

# %%
y_all = LabelEncoder().fit_transform(y_all)
y_all = np_utils.to_categorical(y_all)

X_train, X_valid, y_train, y_valid = train_test_split(X_all, y_all, 
                                                    test_size=0.2, random_state=23, 
                                                    stratify=y_all)

# %%
X_valid
# Out:
# array([[[[  0,   1,   0],
#          [ 46,  52,  51],
#          [ 46,  52,  51],
#          ...,
#          [ 34,  59, 171],
#          [ 24,  50, 184],
#          [ 22,  44, 129]],
#
#         [[ 43,  45,  45],
#          [ 47,  49,  49],
#          [ 48,  50,  50],
#          ...,
#          [ 21,  40, 174],
#          [ 25,  54, 176],
#          [ 21,  40, 102]],
#
#         [[ 39,  39,  39],
#          [ 40,  40,  40],
#          [ 40,  40,  40],
#          ...,
#          [ 39,  53, 151],
#          [ 17,  41, 121],
#          [ 14,  44,  90]],
#
#         ...,
#
#         [[ 32,  40,  39],
#          [ 32,  40,  39],
#          [ 34,  42,  41],
#          ...,
#          [ 40,  37,  33],
#          [ 40,  37,  33],
#          [ 33,  34,  30]],
#
#         [[ 32,  40,  39],
#          [ 32,  40,  39],
#          [ 34,  42,  41],
#          ...,
#          [ 40,  37,  33],
#          [ 40,  37,  33],
#          [ 35,  36,  32]],
#
#         [[ 32,  40,  39],
#          [ 31,  39,  38],
#          [ 33,  41,  40],
#          ...,
#          [ 38,  37,  33],
#          [ 36,  37,  33],
#          [ 34,  35,  31]]],
#
#
#        [[[ 89,  81,  68],
#          [ 88,  81,  64],
#          [ 88,  81,  66],
#          ...,
#          [ 89,  90,  86],
#          [ 89,  90,  86],
#          [ 89,  91,  85]],
#
#         [[ 88,  80,  67],
#          [ 88,  81,  64],
#          [ 88,  81,  66],
#          ...,
#          [ 89,  90,  86],
#          [ 89,  90,  86],
#          [ 89,  91,  85]],
#
#         [[ 86,  78,  65],
#          [ 86,  78,  65],
#          [ 86,  79,  64],
#          ...,
#          [ 90,  92,  86],
#          [ 90,  92,  86],
#          [ 89,  91,  85]],
#
#         ...,
#
#         [[ 50,  58,  57],
#          [ 50,  58,  57],
#          [ 50,  58,  57],
#          ...,
#          [ 90,  92,  80],
#          [ 89,  91,  79],
#          [ 89,  90,  81]],
#
#         [[ 48,  56,  55],
#          [ 50,  58,  57],
#          [ 50,  58,  57],
#          ...,
#          [ 90,  92,  80],
#          [ 89,  91,  79],
#          [ 88,  89,  80]],
#
#         [[ 48,  56,  55],
#          [ 50,  58,  57],
#          [ 50,  58,  57],
#          ...,
#          [ 90,  92,  80],
#          [ 89,  91,  79],
#          [ 88,  89,  80]]],
#
#
#        [[[200, 205, 209],
#          [185, 189, 194],
#          [117, 123, 124],
#          ...,
#          [143, 132, 117],
#          [138, 129, 124],
#          [130, 134, 128]],
#
#         [[106, 106, 107],
#          [124, 128, 127],
#          [119, 123, 124],
#          ...,
#          [147, 131, 118],
#          [141, 128, 127],
#          [138, 136, 135]],
#
#         [[111, 121, 113],
#          [ 87,  95,  86],
#          [ 76,  65,  55],
#          ...,
#          [147, 131, 119],
#          [142, 125, 121],
#          [140, 129, 131]],
#
#         ...,
#
#         [[ 94,  66,  42],
#          [ 97,  70,  43],
#          [100,  74,  44],
#          ...,
#          [158, 123,  79],
#          [181, 108,  43],
#          [185, 110,  56]],
#
#         [[ 94,  66,  42],
#          [ 95,  67,  43],
#          [ 96,  69,  43],
#          ...,
#          [120,  69,  21],
#          [172, 108,  67],
#          [169, 112,  59]],
#
#         [[ 94,  66,  42],
#          [ 95,  67,  43],
#          [ 96,  69,  42],
#          ...,
#          [163, 143, 129],
#          [152, 110,  75],
#          [156, 102,  66]]],
#
#
#        ...,
#
#
#        [[[105,  91,  72],
#          [105,  91,  72],
#          [105,  89,  72],
#          ...,
#          [174, 182, 172],
#          [173, 181, 171],
#          [174, 179, 170]],
#
#         [[104,  89,  73],
#          [137, 122, 106],
#          [121, 109,  95],
#          ...,
#          [174, 182, 172],
#          [172, 180, 170],
#          [174, 179, 170]],
#
#         [[ 93,  82,  68],
#          [119, 108,  94],
#          [107,  98,  84],
#          ...,
#          [174, 182, 172],
#          [174, 182, 172],
#          [176, 181, 172]],
#
#         ...,
#
#         [[ 74,  66,  89],
#          [ 72,  64,  87],
#          [ 70,  64,  87],
#          ...,
#          [195, 201, 184],
#          [195, 201, 184],
#          [194, 200, 183]],
#
#         [[ 69,  63,  86],
#          [ 69,  63,  86],
#          [ 68,  62,  87],
#          ...,
#          [195, 201, 184],
#          [195, 201, 184],
#          [194, 200, 183]],
#
#         [[ 69,  63,  86],
#          [ 69,  63,  86],
#          [ 68,  62,  87],
#          ...,
#          [195, 201, 184],
#          [195, 201, 184],
#          [194, 200, 183]]],
#
#
#        [[[200, 205, 209],
#          [185, 189, 194],
#          [117, 123, 124],
#          ...,
#          [250, 255, 255],
#          [229, 254, 245],
#          [244, 255, 251]],
#
#         [[106, 106, 107],
#          [124, 128, 127],
#          [119, 123, 124],
#          ...,
#          [102,  88,  76],
#          [ 93,  88,  69],
#          [ 92,  86,  68]],
#
#         [[103,  97,  88],
#          [110, 105,  93],
#          [110, 100,  88],
#          ...,
#          [108,  96,  78],
#          [106,  94,  76],
#          [103,  91,  73]],
#
#         ...,
#
#         [[ 80,  80,  89],
#          [ 91,  90,  97],
#          [ 90,  94,  99],
#          ...,
#          [ 54,  62,  61],
#          [ 65,  73,  72],
#          [ 75,  83,  82]],
#
#         [[ 71,  71,  80],
#          [ 81,  80,  87],
#          [ 95,  87,  94],
#          ...,
#          [ 50,  58,  57],
#          [ 61,  69,  68],
#          [ 79,  87,  86]],
#
#         [[ 72,  72,  82],
#          [ 78,  76,  84],
#          [ 80,  84,  90],
#          ...,
#          [ 50,  58,  57],
#          [ 62,  70,  69],
#          [ 71,  79,  78]]],
#
#
#        [[[200, 205, 209],
#          [185, 189, 194],
#          [117, 123, 124],
#          ...,
#          [192, 165, 147],
#          [176, 154, 136],
#          [187, 178, 158]],
#
#         [[106, 106, 107],
#          [124, 128, 127],
#          [119, 123, 124],
#          ...,
#          [206, 189, 171],
#          [184, 154, 137],
#          [173, 156, 137]],
#
#         [[117, 119, 114],
#          [111, 124, 118],
#          [ 86,  72,  64],
#          ...,
#          [218, 215, 202],
#          [188, 153, 137],
#          [178, 155, 137]],
#
#         ...,
#
#         [[ 89,  68,  52],
#          [113,  87,  72],
#          [122,  97,  80],
#          ...,
#          [114,  63,   1],
#          [114,  64,  12],
#          [122,  75,  35]],
#
#         [[ 86,  66,  50],
#          [103,  79,  62],
#          [121,  95,  79],
#          ...,
#          [103,  66,  24],
#          [122,  74,  43],
#          [124,  73,  31]],
#
#         [[ 83,  62,  46],
#          [ 85,  61,  44],
#          [112,  86,  70],
#          ...,
#          [ 96,  70,  53],
#          [102,  67,  41],
#          [117,  71,  15]]]], dtype=uint8)

# %% [markdown]
# ### Описываем модель

# %%
optimizer = RMSprop(lr=1e-4)
objective = 'categorical_crossentropy'

def center_normalize(x):
    return (x - K.mean(x)) / K.std(x)

model = Sequential()

model.add(Activation(activation=center_normalize, input_shape=(ROWS, COLS, CHANNELS)))

model.add(Convolution2D(32, 5, 5, border_mode='same', activation='relu', dim_ordering='tf'))
model.add(Convolution2D(32, 5, 5, border_mode='same', activation='relu', dim_ordering='tf'))
model.add(MaxPooling2D(pool_size=(2, 2), dim_ordering='tf'))

model.add(Convolution2D(64, 3, 3, border_mode='same', activation='relu', dim_ordering='tf'))
model.add(Convolution2D(64, 3, 3, border_mode='same', activation='relu', dim_ordering='tf'))
model.add(MaxPooling2D(pool_size=(2, 2), dim_ordering='tf'))

model.add(Convolution2D(128, 3, 3, border_mode='same', activation='relu', dim_ordering='tf'))
model.add(Convolution2D(128, 3, 3, border_mode='same', activation='relu', dim_ordering='tf'))
model.add(MaxPooling2D(pool_size=(2, 2), dim_ordering='tf'))

model.add(Convolution2D(256, 3, 3, border_mode='same', activation='relu', dim_ordering='tf'))
model.add(Convolution2D(256, 3, 3, border_mode='same', activation='relu', dim_ordering='tf'))
model.add(MaxPooling2D(pool_size=(2, 2), dim_ordering='tf'))


model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(len(FISH_CLASSES)))
model.add(Activation('sigmoid'))

model.compile(loss=objective, optimizer=optimizer)
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (5, 5), activation="relu", padding="same", data_format="channels_last")`
#   # This is added back by InteractiveShellApp.init_path()
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (5, 5), activation="relu", padding="same", data_format="channels_last")`
#   if sys.path[0] == '':
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D(pool_size=(2, 2), data_format="channels_last")`
#   del sys.path[0]
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same", data_format="channels_last")`
#   from ipykernel import kernelapp as app
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same", data_format="channels_last")`
#   app.launch_new_instance()
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D(pool_size=(2, 2), data_format="channels_last")`
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same", data_format="channels_last")`
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same", data_format="channels_last")`
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D(pool_size=(2, 2), data_format="channels_last")`
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same", data_format="channels_last")`
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same", data_format="channels_last")`
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D(pool_size=(2, 2), data_format="channels_last")`

# %% [markdown]
# ### Обучаем модель

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=4, verbose=1, mode='auto')        
        
model.fit(X_train, y_train, batch_size=64, nb_epoch=30,
              validation_split=0.2, verbose=1, shuffle=True, callbacks=[early_stopping])
# Out:
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   after removing the cwd from sys.path.
# Train on 2416 samples, validate on 605 samples
# Epoch 1/30
# INFO:plaidml:Analyzing Ops: 148 of 428 operations complete
# 2368/2416 [============================>.] - ETA: 0s - loss: 1.8113
# INFO:plaidml:Analyzing Ops: 229 of 428 operations complete
# 2416/2416 [==============================] - 60s 25ms/step - loss: 1.8098 - val_loss: 1.6280
# Epoch 2/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.7055 - val_loss: 1.5067
# Epoch 3/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.6321 - val_loss: 1.4950
# Epoch 4/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.5793 - val_loss: 1.3867
# Epoch 5/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.5313 - val_loss: 1.2725
# Epoch 6/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.4624 - val_loss: 1.2709
# Epoch 7/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.4246 - val_loss: 1.1675
# Epoch 8/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.3667 - val_loss: 1.0886
# Epoch 9/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.3035 - val_loss: 1.0019
# Epoch 10/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.2331 - val_loss: 0.9014
# Epoch 11/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.1729 - val_loss: 0.9089
# Epoch 12/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.1379 - val_loss: 0.7980
# Epoch 13/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.0609 - val_loss: 0.7603
# Epoch 14/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 1.0400 - val_loss: 0.7154
# Epoch 15/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.9882 - val_loss: 0.7175
# Epoch 16/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.9331 - val_loss: 0.6640
# Epoch 17/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.8776 - val_loss: 0.6154
# Epoch 18/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.8538 - val_loss: 0.6179
# Epoch 19/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.7933 - val_loss: 0.5704
# Epoch 20/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.7767 - val_loss: 0.5663
# Epoch 21/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.7248 - val_loss: 0.5151
# Epoch 22/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.6973 - val_loss: 0.5022
# Epoch 23/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.6450 - val_loss: 0.4429
# Epoch 24/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.6315 - val_loss: 0.4409
# Epoch 25/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.5716 - val_loss: 0.4111
# Epoch 26/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.5389 - val_loss: 0.3977
# Epoch 27/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.5500 - val_loss: 0.4408
# Epoch 28/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.5144 - val_loss: 0.3718
# Epoch 29/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.4955 - val_loss: 0.3753
# Epoch 30/30
# 2416/2416 [==============================] - 18s 7ms/step - loss: 0.4513 - val_loss: 0.3311

# %%
model.save(TRAIN_DIR+'fish.hdf5')

# %% [markdown]
# ### Предсказываем на тестовой выборке

# %%
preds = model.predict(X_valid, verbose=1)
print("Validation Log Loss: {}".format(log_loss(y_valid, preds)))
# Out:
# 756/756 [==============================] - 11s 15ms/step
# Validation Log Loss: 0.4052794722922978

# %% [markdown]
# ### Предсказание на тестовых данные

# %%
test_files = [im for im in os.listdir(TEST_DIR)]
test = np.ndarray((len(test_files), ROWS, COLS, CHANNELS), dtype=np.uint8)

for i, im in enumerate(test_files): 
    test[i] = read_image(TEST_DIR+im)
    
test_preds = model.predict(test, verbose=1)
# Out:
# 1000/1000 [==============================] - 7s 7ms/step

# %%
submission = pd.DataFrame(test_preds, columns=FISH_CLASSES)
submission.insert(0, 'image', test_files)
submission.head()
# Out:
#            image       ALB       BET       DOL           LAG       NoF  \
# 0  img_00005.jpg  0.000012  0.000148  0.002651  6.645138e-07  0.999987
# 1  img_00007.jpg  0.687716  0.043128  0.000192  7.070927e-02  0.000155
# 2  img_00009.jpg  0.657519  0.024454  0.001641  3.136132e-03  0.023230
# 3  img_00018.jpg  0.999778  0.000030  0.000009  3.653504e-06  0.000043
# 4  img_00027.jpg  0.974481  0.000151  0.000027  1.694440e-06  0.001836
#
#       OTHER     SHARK       YFT
# 0  0.001151  0.000027  0.000074
# 1  0.009721  0.000712  0.712480
# 2  0.791217  0.021765  0.001216
# 3  0.000601  0.000143  0.001106
# 4  0.292069  0.000631  0.008315

# %%
submission.to_csv('finish01.csv',index=0)

# %%
test_files = [im for im in os.listdir(TEST_DIR2)]
test = np.ndarray((len(test_files), ROWS, COLS, CHANNELS), dtype=np.uint8)

for i, im in enumerate(test_files): 
    test[i] = read_image(TEST_DIR2+im)
    
test_preds = model.predict(test, verbose=1)
# Out:
# 12153/12153 [==============================] - 22s 2ms/step

# %%
submission = pd.DataFrame(test_preds, columns=FISH_CLASSES)
submission.insert(0, 'image', test_files)
submission.head()
# Out:
#              image       ALB       BET       DOL       LAG       NoF  \
# 0  image_00001.jpg  0.393065  0.009546  0.005114  0.004779  0.028188
# 1  image_00002.jpg  0.926306  0.000117  0.000292  0.000007  0.061138
# 2  image_00003.jpg  0.011997  0.003176  0.000530  0.000457  0.923168
# 3  image_00004.jpg  0.999689  0.000835  0.000234  0.000167  0.000851
# 4  image_00005.jpg  0.407196  0.070673  0.002678  0.000582  0.002704
#
#       OTHER     SHARK       YFT
# 0  0.803224  0.016912  0.038505
# 1  0.007320  0.000236  0.000724
# 2  0.427791  0.001482  0.027691
# 3  0.000178  0.000500  0.014636
# 4  0.009390  0.000954  0.280414

# %%
submission.to_csv('finish02.csv',index=0)
